# %% [markdown]
# <a href="https://colab.research.google.com/github/Harnoor001/PDF-Reorder/blob/main/PDF_Reorder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymupdf > /dev/null

from google.colab import files
import fitz  # PyMuPDF

print("Upload your PDF to reorder pages:")
uploaded = files.upload()
input_pdf = list(uploaded.keys())[0]

doc = fitz.open(input_pdf)
total_pages = len(doc)
doc.close()
print(f"✅ Uploaded '{input_pdf}' with {total_pages} pages (0-indexed).")

order_input = input(f"✏️ Enter new page order (comma-separated, e.g., 2,0,1):\n")
page_order = [int(i.strip()) for i in order_input.split(",")]

doc = fitz.open(input_pdf)
new_doc = fitz.open()
for i in page_order:
    temp = fitz.open()
    temp.insert_pdf(doc, from_page=i, to_page=i)
    new_doc.insert_pdf(temp)
    temp.close()
output_pdf = "reordered_output.pdf"
new_doc.save(output_pdf)
new_doc.close()
doc.close()
print(f"✅ PDF reordered and saved as '{output_pdf}'.")

files.download(output_pdf)
# Out:
# 📤 Upload your PDF to reorder pages:
#      <input type="file" id="files-4a5a5be7-2fc0-4096-9e62-3fad936ec116" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a5a5be7-2fc0-4096-9e62-3fad936ec116">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
